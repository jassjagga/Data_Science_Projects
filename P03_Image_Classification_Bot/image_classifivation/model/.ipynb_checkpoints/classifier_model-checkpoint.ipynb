# %%
import numpy as np 
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread("./test_images/images.jpg")
img.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(img)

# %%
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (225, 225)

# %%
plt.imshow(gray,cmap="gray")

# %%
gray
# Out:
# array([[184, 185, 186, ..., 225, 225, 226],
#        [185, 185, 186, ..., 225, 225, 226],
#        [185, 186, 187, ..., 225, 224, 225],
#        ...,
#        [ 11,  11,  11, ...,  11,  11,  11],
#        [ 11,  11,  10, ...,  11,  11,  11],
#        [ 13,  13,  12, ...,  11,  11,  10]], dtype=uint8)

# %%
#face_cascade=cv2.CascadeClassifier("C:\github\Data_Science_Projects\P03_Image_Classification_Bot\image_classifivation\model\opencv\haarcascades\haarcascade_frontalface_default.xml")
#eye_cascade=cv2.CascadeClassifier("C:\github\Data_Science_Projects\P03_Image_Classification_Bot\image_classifivation\model\opencv\haarcascades\haarcascade_eyes.xml")

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
faces=face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[ 50,  28, 145, 145]])

# %%
(x,y,w,h)=faces[0]
x,y,w,h
# Out:
# (50, 28, 145, 145)

# %%
face_img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for(x,y,w,h)in faces:
        center = (x + w//2, y + h//2)
        frame = cv2.ellipse(img, center, (w//2, h//2), 0, 0, 360, (255, 0, 255), 4)
        faceROI = gray[y:y+h,x:x+w]
        #-- In each face, detect eyes
        eyes = eye_cascade.detectMultiScale(faceROI)
        for (x2,y2,w2,h2) in eyes:
            eye_center = (x + x2 + w2//2, y + y2 + h2//2)
            radius = int(round((w2 + h2)*0.25))
            frame = cv2.circle(frame, eye_center, radius, (255, 0, 0 ), 2)

                
plt.figure()
plt.imshow(frame, cmap="gray")
plt.show()

# %%
# %matplotlib inline
plt.imshow(faceROI,cmap="gray")              #roi means region of interest

# %%
def get_cropped_image_if_2_eyes(image_path):
    img=cv2.imread(image_path)
    if img is not None:
        gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        faces=face_cascade.detectMultiScale(gray,1.3,5)
        for (x,y,w,h) in faces:
            roi_gray=gray[y:y+h,x:x+w]
            roi_color=img[y:y+h,x:x+w]
            eyes=eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >=2:
                return roi_color

# %%
orginal_image=cv2.imread("./test_images/images.jpg")
plt.imshow(orginal_image)

# %%
croped_image=get_cropped_image_if_2_eyes("./test_images/images.jpg")
plt.imshow(croped_image)

# %%
orginal_image2=cv2.imread("./test_images/image4.jpg")
plt.imshow(orginal_image2)

# %%
croped_image1=get_cropped_image_if_2_eyes("./test_images/image4.jpg")
croped_image1

# %%
path_to_data="./dataset/"
path_to_cr_data="./dataset/cropped/"

# %%
import os
img_dirs=[]
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Amir_Khan',
#  './dataset/cropped',
#  './dataset/elli_ebrahim',
#  './dataset/elon_musk',
#  './dataset/gwynne_shotwell',
#  './dataset/tom_hanks']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
path="./dataset/tom_hanks/"
filenames=os.listdir(path)
for filename in filenames:
    os.rename(os.path.join(path,filename),os.path.join(path, filename.replace(" ","_")))

# %%
cropped_image_dirs=[]
celebrity_file_names_dict={}

for img_dir in img_dirs:
    count= 1
    celebrity_name=img_dir.split("/")[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color=get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder=path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("generating cropped images in folder: ",cropped_folder)
            
            cropped_file_name=celebrity_name +str(count) + ".png"
            cropped_file_path=cropped_folder + "/" + cropped_file_name
            
            cv2.imwrite(cropped_file_path,roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Amir_Khan
# generating cropped images in folder:  ./dataset/cropped/Amir_Khan
# cropped
# elli_ebrahim
# generating cropped images in folder:  ./dataset/cropped/elli_ebrahim
# elon_musk
# generating cropped images in folder:  ./dataset/cropped/elon_musk
# gwynne_shotwell
# generating cropped images in folder:  ./dataset/cropped/gwynne_shotwell
# tom_hanks
# generating cropped images in folder:  ./dataset/cropped/tom_hanks

# %%
celebrity_file_names_dict={}
for img_dir in cropped_image_dirs:
    celebrity_name=img_dir.split("/")[-1]
    file_list=[]
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Amir_Khan': ['./dataset/cropped/Amir_Khan\\Amir_Khan1.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan10.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan11.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan12.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan13.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan14.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan15.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan16.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan17.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan18.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan19.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan2.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan20.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan21.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan22.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan23.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan24.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan26.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan27.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan28.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan29.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan3.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan30.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan31.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan32.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan33.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan35.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan36.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan37.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan38.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan39.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan4.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan41.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan42.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan43.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan44.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan45.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan46.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan47.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan48.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan49.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan5.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan51.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan52.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan53.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan54.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan55.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan56.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan57.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan58.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan59.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan6.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan60.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan63.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan64.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan65.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan67.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan68.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan7.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan70.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan71.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan73.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan8.png',
#   './dataset/cropped/Amir_Khan\\Amir_Khan9.png'],
#  'elli_ebrahim': ['./dataset/cropped/elli_ebrahim\\elli_ebrahim1.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim10.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim100.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim101.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim102.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim103.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim104.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim105.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim106.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim108.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim109.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim11.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim110.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim111.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim112.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim12.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim13.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim14.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim15.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim17.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim18.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim19.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim2.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim20.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim21.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim22.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim23.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim24.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim25.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim26.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim27.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim28.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim29.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim3.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim30.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim31.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim32.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim35.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim36.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim37.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim38.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim39.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim4.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim40.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim41.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim42.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim43.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim44.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim45.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim46.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim47.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim48.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim49.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim5.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim50.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim51.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim52.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim53.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim54.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim55.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim56.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim57.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim58.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim59.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim6.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim60.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim61.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim62.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim63.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim64.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim65.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim66.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim67.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim68.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim69.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim7.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim70.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim71.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim72.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim73.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim74.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim75.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim76.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim77.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim78.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim79.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim8.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim80.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim81.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim82.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim84.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim85.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim86.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim87.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim88.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim9.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim90.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim91.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim92.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim93.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim94.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim95.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim96.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim97.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim98.png',
#   './dataset/cropped/elli_ebrahim\\elli_ebrahim99.png'],
#  'elon_musk': ['./dataset/cropped/elon_musk\\elon_musk1.png',
#   './dataset/cropped/elon_musk\\elon_musk10.png',
#   './dataset/cropped/elon_musk\\elon_musk11.png',
#   './dataset/cropped/elon_musk\\elon_musk12.png',
#   './dataset/cropped/elon_musk\\elon_musk13.png',
#   './dataset/cropped/elon_musk\\elon_musk14.png',
#   './dataset/cropped/elon_musk\\elon_musk15.png',
#   './dataset/cropped/elon_musk\\elon_musk16.png',
#   './dataset/cropped/elon_musk\\elon_musk17.png',
#   './dataset/cropped/elon_musk\\elon_musk18.png',
#   './dataset/cropped/elon_musk\\elon_musk19.png',
#   './dataset/cropped/elon_musk\\elon_musk2.png',
#   './dataset/cropped/elon_musk\\elon_musk21.png',
#   './dataset/cropped/elon_musk\\elon_musk22.png',
#   './dataset/cropped/elon_musk\\elon_musk23.png',
#   './dataset/cropped/elon_musk\\elon_musk24.png',
#   './dataset/cropped/elon_musk\\elon_musk25.png',
#   './dataset/cropped/elon_musk\\elon_musk26.png',
#   './dataset/cropped/elon_musk\\elon_musk27.png',
#   './dataset/cropped/elon_musk\\elon_musk28.png',
#   './dataset/cropped/elon_musk\\elon_musk29.png',
#   './dataset/cropped/elon_musk\\elon_musk3.png',
#   './dataset/cropped/elon_musk\\elon_musk30.png',
#   './dataset/cropped/elon_musk\\elon_musk31.png',
#   './dataset/cropped/elon_musk\\elon_musk32.png',
#   './dataset/cropped/elon_musk\\elon_musk33.png',
#   './dataset/cropped/elon_musk\\elon_musk34.png',
#   './dataset/cropped/elon_musk\\elon_musk36.png',
#   './dataset/cropped/elon_musk\\elon_musk37.png',
#   './dataset/cropped/elon_musk\\elon_musk38.png',
#   './dataset/cropped/elon_musk\\elon_musk39.png',
#   './dataset/cropped/elon_musk\\elon_musk4.png',
#   './dataset/cropped/elon_musk\\elon_musk40.png',
#   './dataset/cropped/elon_musk\\elon_musk41.png',
#   './dataset/cropped/elon_musk\\elon_musk42.png',
#   './dataset/cropped/elon_musk\\elon_musk43.png',
#   './dataset/cropped/elon_musk\\elon_musk44.png',
#   './dataset/cropped/elon_musk\\elon_musk45.png',
#   './dataset/cropped/elon_musk\\elon_musk46.png',
#   './dataset/cropped/elon_musk\\elon_musk47.png',
#   './dataset/cropped/elon_musk\\elon_musk49.png',
#   './dataset/cropped/elon_musk\\elon_musk5.png',
#   './dataset/cropped/elon_musk\\elon_musk50.png',
#   './dataset/cropped/elon_musk\\elon_musk51.png',
#   './dataset/cropped/elon_musk\\elon_musk52.png',
#   './dataset/cropped/elon_musk\\elon_musk53.png',
#   './dataset/cropped/elon_musk\\elon_musk54.png',
#   './dataset/cropped/elon_musk\\elon_musk55.png',
#   './dataset/cropped/elon_musk\\elon_musk56.png',
#   './dataset/cropped/elon_musk\\elon_musk57.png',
#   './dataset/cropped/elon_musk\\elon_musk58.png',
#   './dataset/cropped/elon_musk\\elon_musk59.png',
#   './dataset/cropped/elon_musk\\elon_musk6.png',
#   './dataset/cropped/elon_musk\\elon_musk60.png',
#   './dataset/cropped/elon_musk\\elon_musk61.png',
#   './dataset/cropped/elon_musk\\elon_musk62.png',
#   './dataset/cropped/elon_musk\\elon_musk63.png',
#   './dataset/cropped/elon_musk\\elon_musk64.png',
#   './dataset/cropped/elon_musk\\elon_musk65.png',
#   './dataset/cropped/elon_musk\\elon_musk66.png',
#   './dataset/cropped/elon_musk\\elon_musk67.png',
#   './dataset/cropped/elon_musk\\elon_musk7.png',
#   './dataset/cropped/elon_musk\\elon_musk8.png',
#   './dataset/cropped/elon_musk\\elon_musk9.png'],
#  'gwynne_shotwell': ['./dataset/cropped/gwynne_shotwell\\gwynne_shotwell10.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell100.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell101.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell102.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell103.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell105.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell106.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell107.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell108.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell109.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell11.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell110.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell111.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell112.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell113.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell114.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell116.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell117.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell118.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell119.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell12.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell120.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell121.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell123.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell13.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell14.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell15.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell16.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell17.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell18.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell19.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell2.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell20.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell21.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell22.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell23.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell24.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell25.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell26.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell27.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell29.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell3.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell30.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell31.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell32.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell33.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell34.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell35.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell36.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell37.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell38.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell39.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell4.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell40.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell41.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell42.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell43.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell44.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell45.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell46.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell47.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell48.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell49.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell5.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell50.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell51.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell54.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell55.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell56.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell57.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell58.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell59.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell6.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell61.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell65.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell66.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell67.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell7.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell70.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell71.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell73.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell74.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell75.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell76.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell77.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell78.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell79.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell81.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell82.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell85.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell87.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell88.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell89.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell9.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell93.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell95.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell96.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell97.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell98.png',
#   './dataset/cropped/gwynne_shotwell\\gwynne_shotwell99.png'],
#  'tom_hanks': ['./dataset/cropped/tom_hanks\\tom_hanks1.png',
#   './dataset/cropped/tom_hanks\\tom_hanks10.png',
#   './dataset/cropped/tom_hanks\\tom_hanks11.png',
#   './dataset/cropped/tom_hanks\\tom_hanks14.png',
#   './dataset/cropped/tom_hanks\\tom_hanks15.png',
#   './dataset/cropped/tom_hanks\\tom_hanks16.png',
#   './dataset/cropped/tom_hanks\\tom_hanks17.png',
#   './dataset/cropped/tom_hanks\\tom_hanks18.png',
#   './dataset/cropped/tom_hanks\\tom_hanks19.png',
#   './dataset/cropped/tom_hanks\\tom_hanks2.png',
#   './dataset/cropped/tom_hanks\\tom_hanks20.png',
#   './dataset/cropped/tom_hanks\\tom_hanks21.png',
#   './dataset/cropped/tom_hanks\\tom_hanks22.png',
#   './dataset/cropped/tom_hanks\\tom_hanks23.png',
#   './dataset/cropped/tom_hanks\\tom_hanks25.png',
#   './dataset/cropped/tom_hanks\\tom_hanks26.png',
#   './dataset/cropped/tom_hanks\\tom_hanks27.png',
#   './dataset/cropped/tom_hanks\\tom_hanks28.png',
#   './dataset/cropped/tom_hanks\\tom_hanks29.png',
#   './dataset/cropped/tom_hanks\\tom_hanks30.png',
#   './dataset/cropped/tom_hanks\\tom_hanks31.png',
#   './dataset/cropped/tom_hanks\\tom_hanks34.png',
#   './dataset/cropped/tom_hanks\\tom_hanks38.png',
#   './dataset/cropped/tom_hanks\\tom_hanks39.png',
#   './dataset/cropped/tom_hanks\\tom_hanks4.png',
#   './dataset/cropped/tom_hanks\\tom_hanks40.png',
#   './dataset/cropped/tom_hanks\\tom_hanks41.png',
#   './dataset/cropped/tom_hanks\\tom_hanks42.png',
#   './dataset/cropped/tom_hanks\\tom_hanks43.png',
#   './dataset/cropped/tom_hanks\\tom_hanks44.png',
#   './dataset/cropped/tom_hanks\\tom_hanks45.png',
#   './dataset/cropped/tom_hanks\\tom_hanks46.png',
#   './dataset/cropped/tom_hanks\\tom_hanks47.png',
#   './dataset/cropped/tom_hanks\\tom_hanks48.png',
#   './dataset/cropped/tom_hanks\\tom_hanks5.png',
#   './dataset/cropped/tom_hanks\\tom_hanks50.png',
#   './dataset/cropped/tom_hanks\\tom_hanks51.png',
#   './dataset/cropped/tom_hanks\\tom_hanks52.png',
#   './dataset/cropped/tom_hanks\\tom_hanks53.png',
#   './dataset/cropped/tom_hanks\\tom_hanks54.png',
#   './dataset/cropped/tom_hanks\\tom_hanks55.png',
#   './dataset/cropped/tom_hanks\\tom_hanks56.png',
#   './dataset/cropped/tom_hanks\\tom_hanks57.png',
#   './dataset/cropped/tom_hanks\\tom_hanks58.png',
#   './dataset/cropped/tom_hanks\\tom_hanks59.png',
#   './dataset/cropped/tom_hanks\\tom_hanks6.png',
#   './dataset/cropped/tom_hanks\\tom_hanks60.png',
#   './dataset/cropped/tom_hanks\\tom_hanks62.png',
#   './dataset/cropped/tom_hanks\\tom_hanks63.png',
#   './dataset/cropped/tom_hanks\\tom_hanks64.png',
#   './dataset/cropped/tom_hanks\\tom_hanks65.png',
#   './dataset/cropped/tom_hanks\\tom_hanks66.png',
#   './dataset/cropped/tom_hanks\\tom_hanks67.png',
#   './dataset/cropped/tom_hanks\\tom_hanks68.png',
#   './dataset/cropped/tom_hanks\\tom_hanks69.png',
#   './dataset/cropped/tom_hanks\\tom_hanks7.png',
#   './dataset/cropped/tom_hanks\\tom_hanks70.png',
#   './dataset/cropped/tom_hanks\\tom_hanks71.png',
#   './dataset/cropped/tom_hanks\\tom_hanks8.png',
#   './dataset/cropped/tom_hanks\\tom_hanks9.png']}

# %%
import numpy as np 
import pywt
import cv2

def w2d(img, mode="haar",level=1):
    imArray=img
    #datatype conversions
    #convert to grayscale
    imArray=cv2.cvtColor(imArray,cv2.COLOR_RGB2GRAY)
    #CONVERT TO FLOT
    imArray=np.float32(imArray)
    imArray/=255;
    #computer coefficients
    coeffs=pywt.wavedec2(imArray, mode,level=level)
    
    #Process Coefficients
    coeffs_H=list(coeffs)
    coeffs_H[0] *=0;
    
    #Reconstruction 
    imArray_H=pywt.waverec2(coeffs_H,mode);
    imArray_H *= 255;
    imArray_H= np.uint8(imArray_H)
    
    return imArray_H

# %%
im_har=w2d(croped_image,"db1",5)
plt.imshow(im_har,cmap="gray")

# %%
class_dict={}
count=0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name]=count
    count=count+1
class_dict
# Out:
# {'Amir_Khan': 0,
#  'elli_ebrahim': 1,
#  'elon_musk': 2,
#  'gwynne_shotwell': 3,
#  'tom_hanks': 4}

# %%
# we are vertically stacking the images orginal image plus the wavelet transfer image
x = []
y = []

for celebrity_name,training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img=cv2.imread(training_image)
        scalled_raw_img=cv2.resize(img,(32,32))
        img_har=w2d(img,"db1",5)
        scalled_img_har=cv2.resize(img_har,(32,32))
        combined_img= np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        x.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
32*32*3 +32*32
# Out:
# 4096

# %%
len(x[0])
# Out:
# 4096

# %%
x[0]
# Out:
# array([[ 44],
#        [ 60],
#        [ 76],
#        ...,
#        [240],
#        [246],
#        [ 15]], dtype=uint8)

# %%
x= np.array(x).reshape(len(x),4096).astype(float)
x.shape
# Out:
# (394, 4096)

# %%
x[0]
# Out:
# array([ 44.,  60.,  76., ..., 240., 246.,  15.])

# %% [markdown]
# ### training the model using svm

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train,X_test,y_train,y_test= train_test_split(x,y,random_state=0)

pipe=Pipeline([("scaler",StandardScaler()),("svc",SVC(kernel="rbf",C=10))])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.8787878787878788

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.67      0.77        18
#            1       0.96      0.89      0.92        27
#            2       0.91      1.00      0.95        10
#            3       0.93      0.96      0.95        27
#            4       0.68      0.88      0.77        17
#
#     accuracy                           0.88        99
#    macro avg       0.88      0.88      0.87        99
# weighted avg       0.89      0.88      0.88        99

# %% [markdown]
# #### GridSearchCV

# %%
from sklearn import svm 
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params={
    "svm":{
        "model":svm.SVC(gamma="auto",probability=True),
        "params":{
            "svc__C":[1,10,100,1000],
            "svc__kernel":["rbf","linear"]
        }
    },
    "random_forest":{
        "model": RandomForestClassifier(),
        "params":{
            "randomforestclassifier__n_estimators":[1,5,10]
        }
    },
    "logistic_regression":{
        "model":LogisticRegression(solver="liblinear",multi_class="auto"),
        "params":{
            "logisticregression__C":[1,5,10]
        }
    }
}

# %%
scores=[]
best_estimators={}

import pandas as pd
for algo,mp in model_params.items():
    pipe=make_pipeline(StandardScaler(),mp["model"])
    clf=GridSearchCV(pipe,mp["params"],cv=5,return_train_score=False)
    clf.fit(X_train,y_train)
    scores.append({
        "model":algo,
        "best_scores":clf.best_score_,
        "best_params":clf.best_params_
    })
    best_estimators[algo]=clf.best_estimator_

df= pd.DataFrame(scores,columns=["model","best_scores","best_params"])
df
# Out:
#                  model  best_scores  \
# 0                  svm     0.837288
# 1        random_forest     0.586441
# 2  logistic_regression     0.820339
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 5}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=5, solver='liblinear'))])}

# %%
best_estimators["svm"].score(X_test,y_test)
# Out:
# 0.8787878787878788

# %%
best_estimators["random_forest"].score(X_test,y_test)
# Out:
# 0.7272727272727273

# %%
best_estimators["logistic_regression"].score(X_test,y_test)
# Out:
# 0.9191919191919192

# %%
best_clf=best_estimators["logistic_regression"]

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,best_clf.predict(X_test))
cm
# Out:
# array([[15,  0,  1,  0,  2],
#        [ 0, 24,  0,  2,  1],
#        [ 0,  0, 10,  0,  0],
#        [ 0,  0,  0, 27,  0],
#        [ 1,  0,  1,  0, 15]], dtype=int64)

# %%
import seaborn as sn 
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Amir_Khan': 0,
#  'elli_ebrahim': 1,
#  'elon_musk': 2,
#  'gwynne_shotwell': 3,
#  'tom_hanks': 4}

# %%
# !pip install joblib
import joblib
joblib.dump(best_clf,"save_model.pkl")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\anaconda\lib\site-packages (1.1.0)
# ['save_model.pkl']

# %%
 import json
with open("class_dictionary.json","w")as f:
    f.write(json.dumps(class_dict))
